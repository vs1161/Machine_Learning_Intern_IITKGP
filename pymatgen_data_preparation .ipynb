# %%
import pymatgen

# %%
from pymatgen.core.periodic_table import Element

# %%
element_data = []
for element in Element:
    symbol = element.symbol
    atomic_number = element.Z
    atomic_mass = element.atomic_mass
    if (element.molar_volume == None):
        molar_volume = 0.0
    else:
        molar_volume = element.molar_volume
    element_data.append((symbol , atomic_number , atomic_mass , molar_volume))
element_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       4 atomic_number = element.Z
#       5 atomic_mass = element.atomic_mass
# ----> 6 if (element.molar_volume == None):
#       7     molar_volume = 0.0
#       8 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymatgen\core\periodic_table.py:288, in ElementBase.__getattr__(self, item)
#     286 else:
#     287     try:
# --> 288         val = float(val)
#     289     except ValueError:
#     290         nobracket = re.sub(r"\(.*\)", "", val)
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'

# %%
elements
# Out:
# [('H', 1, 1.00794, 'Hydrogen'),
#  ('He', 2, 4.002602, 'Helium'),
#  ('Li', 3, 6.941, 'Lithium'),
#  ('Be', 4, 9.012182, 'Beryllium'),
#  ('B', 5, 10.811, 'Boron'),
#  ('C', 6, 12.0107, 'Carbon'),
#  ('N', 7, 14.0067, 'Nitrogen'),
#  ('O', 8, 15.9994, 'Oxygen'),
#  ('F', 9, 18.9984032, 'Fluorine'),
#  ('Ne', 10, 20.1797, 'Neon'),
#  ('Na', 11, 22.98976928, 'Sodium'),
#  ('Mg', 12, 24.305, 'Magnesium'),
#  ('Al', 13, 26.9815386, 'Aluminum'),
#  ('Si', 14, 28.0855, 'Silicon'),
#  ('P', 15, 30.973762, 'Phosphorus'),
#  ('S', 16, 32.065, 'Sulfur'),
#  ('Cl', 17, 35.453, 'Chlorine'),
#  ('Ar', 18, 39.948, 'Argon'),
#  ('K', 19, 39.0983, 'Potassium'),
#  ('Ca', 20, 40.078, 'Calcium'),
#  ('Sc', 21, 44.955912, 'Scandium'),
#  ('Ti', 22, 47.867, 'Titanium'),
#  ('V', 23, 50.9415, 'Vanadium'),
#  ('Cr', 24, 51.9961, 'Chromium'),
#  ('Mn', 25, 54.938045, 'Manganese'),
#  ('Fe', 26, 55.845, 'Iron'),
#  ('Co', 27, 58.933195, 'Cobalt'),
#  ('Ni', 28, 58.6934, 'Nickel'),
#  ('Cu', 29, 63.546, 'Copper'),
#  ('Zn', 30, 65.409, 'Zinc'),
#  ('Ga', 31, 69.723, 'Gallium'),
#  ('Ge', 32, 72.64, 'Germanium'),
#  ('As', 33, 74.9216, 'Arsenic'),
#  ('Se', 34, 78.96, 'Selenium'),
#  ('Br', 35, 79.904, 'Bromine'),
#  ('Kr', 36, 83.798, 'Krypton'),
#  ('Rb', 37, 85.4678, 'Rubidium'),
#  ('Sr', 38, 87.62, 'Strontium'),
#  ('Y', 39, 88.90585, 'Yttrium'),
#  ('Zr', 40, 91.224, 'Zirconium'),
#  ('Nb', 41, 92.90638, 'Niobium'),
#  ('Mo', 42, 95.94, 'Molybdenum'),
#  ('Tc', 43, 98.0, 'Technetium'),
#  ('Ru', 44, 101.07, 'Ruthenium'),
#  ('Rh', 45, 102.9055, 'Rhodium'),
#  ('Pd', 46, 106.42, 'Palladium'),
#  ('Ag', 47, 107.8682, 'Silver'),
#  ('Cd', 48, 112.411, 'Cadmium'),
#  ('In', 49, 114.818, 'Indium'),
#  ('Sn', 50, 118.71, 'Tin'),
#  ('Sb', 51, 121.76, 'Antimony'),
#  ('Te', 52, 127.6, 'Tellurium'),
#  ('I', 53, 126.90447, 'Iodine'),
#  ('Xe', 54, 131.293, 'Xenon'),
#  ('Cs', 55, 132.9054519, 'Cesium'),
#  ('Ba', 56, 137.327, 'Barium'),
#  ('La', 57, 138.90547, 'Lanthanum'),
#  ('Ce', 58, 140.116, 'Cerium'),
#  ('Pr', 59, 140.90765, 'Praseodymium'),
#  ('Nd', 60, 144.242, 'Neodymium'),
#  ('Pm', 61, 145.0, 'Promethium'),
#  ('Sm', 62, 150.36, 'Samarium'),
#  ('Eu', 63, 151.964, 'Europium'),
#  ('Gd', 64, 157.25, 'Gadolinium'),
#  ('Tb', 65, 158.92535, 'Terbium'),
#  ('Dy', 66, 162.5, 'Dysprosium'),
#  ('Ho', 67, 164.93032, 'Holmium'),
#  ('Er', 68, 167.259, 'Erbium'),
#  ('Tm', 69, 168.93421, 'Thulium'),
#  ('Yb', 70, 173.04, 'Ytterbium'),
#  ('Lu', 71, 174.967, 'Lutetium'),
#  ('Hf', 72, 178.49, 'Hafnium'),
#  ('Ta', 73, 180.94788, 'Tantalum'),
#  ('W', 74, 183.84, 'Tungsten'),
#  ('Re', 75, 186.207, 'Rhenium'),
#  ('Os', 76, 190.23, 'Osmium'),
#  ('Ir', 77, 192.217, 'Iridium'),
#  ('Pt', 78, 195.084, 'Platinum'),
#  ('Au', 79, 196.966569, 'Gold'),
#  ('Hg', 80, 200.59, 'Mercury'),
#  ('Tl', 81, 204.3833, 'Thallium'),
#  ('Pb', 82, 207.2, 'Lead'),
#  ('Bi', 83, 208.9804, 'Bismuth'),
#  ('Po', 84, 210.0, 'Polonium'),
#  ('At', 85, 210.0, 'Astatine'),
#  ('Rn', 86, 220.0, 'Radon'),
#  ('Fr', 87, 223.0, 'Francium'),
#  ('Ra', 88, 226.0, 'Radium'),
#  ('Ac', 89, 227.0, 'Actinium'),
#  ('Th', 90, 232.03806, 'Thorium'),
#  ('Pa', 91, 231.03588, 'Protactinium'),
#  ('U', 92, 238.02891, 'Uranium'),
#  ('Np', 93, 237.0, 'Neptunium'),
#  ('Pu', 94, 244.0, 'Plutonium'),
#  ('Am', 95, 243.0, 'Americium'),
#  ('Cm', 96, 247.0, 'Curium'),
#  ('Bk', 97, 247.0, 'Berkelium'),
#  ('Cf', 98, 251.0, 'Californium'),
#  ('Es', 99, 252.0, 'Einsteinium'),
#  ('Fm', 100, 257.0, 'Fermium'),
#  ('Md', 101, 258.0, 'Mendelevium'),
#  ('No', 102, 259.0, 'Nobelium'),
#  ('Lr', 103, 262.0, 'Lawrencium'),
#  ('Rf', 104, 267.0, 'Rutherfordium'),
#  ('Db', 105, 268.0, 'Dubnium'),
#  ('Sg', 106, 269.0, 'Seaborgium'),
#  ('Bh', 107, 270.0, 'Bohrium'),
#  ('Hs', 108, 270.0, 'Hassium'),
#  ('Mt', 109, 278.0, 'Meitnerium'),
#  ('Ds', 110, 281.0, 'Darmstadtium'),
#  ('Rg', 111, 282.0, 'Roentgenium'),
#  ('Cn', 112, 285.0, 'Copernicium'),
#  ('Nh', 113, 286.0, 'Nihonium'),
#  ('Fl', 114, 289.0, 'Flerovium'),
#  ('Mc', 115, 290.0, 'Moscovium'),
#  ('Lv', 116, 293.0, 'Livermorium'),
#  ('Ts', 117, 294.0, 'Tennessine'),
#  ('Og', 118, 2949.0, 'Oganesson')]

# %%
import pandas as pd 
df = pd.DataFrame(elements)

# %%
df
# Out:
#       0    1            2            3
# 0     H    1     1.007940     Hydrogen
# 1    He    2     4.002602       Helium
# 2    Li    3     6.941000      Lithium
# 3    Be    4     9.012182    Beryllium
# 4     B    5    10.811000        Boron
# ..   ..  ...          ...          ...
# 113  Fl  114   289.000000    Flerovium
# 114  Mc  115   290.000000    Moscovium
# 115  Lv  116   293.000000  Livermorium
# 116  Ts  117   294.000000   Tennessine
# 117  Og  118  2949.000000    Oganesson
#
# [118 rows x 4 columns]
